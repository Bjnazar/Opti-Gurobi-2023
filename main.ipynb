# %%
from gurobipy import GRB, Model, quicksum, GurobiError
import random

# Constantes
N_ELECTRICOS = 8
N_DIESEL = 8
N_DESTINOS = 10
N_ORIGENES = 10
N_DIAS = 5
bigM = 10**5

distancias1 = [28, 366, 644, 101, 392, 306, 356, 171, 360, 363]  # origen
distancias2 = [546, 205, 41, 559, 304, 244, 35, 80, 59, 197]  # destino
tpo_en_bloques1 = [1, 11, 19, 3, 12, 9, 11, 5, 11, 11]  # origen
tpo_en_bloques2 = [16, 6, 2, 16, 9, 7, 1, 3, 2, 6]  # destino

emisiones = [0.002064, 0.002114, 0.001994, 0.001961, 0.002064, 0.002114, 0.001994, 0.001961,  0, 0, 0, 0, 0, 0, 0, 0]
autonomias = [644, 483, 563, 523, 644, 483, 563, 523, 643, 150, 150, 250, 643, 150, 150, 250]
precios = [19900000,158852500,277197590,84440000,19900000,158852500,277197590,84440000,118000000,95000000,90000000,138000000,118000000,95000000,90000000,138000000]
precios = [p/10**6 for p in precios]  # Precios en millones de pesos
costos_km = [800,820,774,761,800,820,774,761,113,170,170,226,113,170,170,226]
costos_km = [c/10**6 for c in costos_km]  # Precios en millones de pesos
capacidades = [120,119,202,63,120,119,202,63,106,129,120,183,106,129,120,183]
bloques_origenes = [1,11,19,3,12,9,11,5,11,11]
bloques_destinos = [16,6,2,16,9,7,1,3,2,6]

Camiones = range(1, N_DIESEL + N_ELECTRICOS + 1)  # i in I
Destinos = range(1, N_DESTINOS + 1)  # d in D
Origenes = range(1, N_ORIGENES + 1)  # o in O
Dias = range(1, N_DIAS + 1)  # t in T
Bloques = range(1, 48 + 1)  # b in {1,...,48}

V = {i: 140 for i in Camiones}  # V_i
A = dict(zip(list(Camiones), autonomias))
E = dict(zip(list(Camiones), emisiones))
Ckm = dict(zip(list(Camiones), costos_km))
Cc = dict(zip(list(Camiones), precios))
Q = dict(zip(list(Camiones), capacidades))
Do = [28, 366, 644, 101, 392, 306, 356, 171, 360, 363]
Dd = [ 546, 205, 41, 559, 304, 244, 35, 80, 59, 197]
Md = {(1, 1): 53, (1, 2): 54, (1, 3): 78, (1, 4): 52, (1, 5): 59, (2, 1): 81, (2, 2): 76, (2, 3): 63, (2, 4): 80, (2, 5): 56, (3, 1): 54, (3, 2): 70, (3, 3): 53, (3, 4): 57, (3, 5): 77, (4, 1): 67, (4, 2): 81, (4, 3): 63, (4, 4): 88, (4, 5): 70, (5, 1): 58, (5, 2): 74, (5, 3): 70, (5, 4): 81, (5, 5): 60, (6, 1): 77, (6, 2): 79, (6, 3): 71, (6, 4): 72, (6, 5): 76, (7, 1): 53, (7, 2): 53, (7, 3): 67, (7, 4): 62, (7, 5): 79, (8, 1): 53, (8, 2): 71, (8, 3): 62, (8, 4): 64, (8, 5): 62, (9, 1): 85, (9, 2): 76, (9, 3): 90, (9, 4): 82, (9, 5): 63, (10, 1): 89, (10, 2): 74, (10, 3): 83, (10, 4): 74, (10, 5): 72}
R = {1: 48, 2: 57, 3: 81, 4: 33, 5: 111, 6: 102, 7: 100, 8: 29, 9: 105, 10: 106}  # el origen que está más cerca ofrece menos
Bo = {(i, o):bloques_origenes[o - 1] for o in Origenes for i in Camiones}
Bd = {(i, d): bloques_destinos[d - 1] for d in Destinos for i in Camiones}
tmaxd = 10
Cq = 20000
Qmax = 500
Ce = 5000
G = 500 * 1  # Para ajustar presupuesto

# %%
random.seed(42)
Md = dict()  # demandas de cada destino en cada día: llaves (d, t)
for t in range(1, N_DIAS + 1): 
    for d in Destinos:
        Md[(d,t)] = random.randint(50,90)
for k in Md.keys(): Md[k] = 1 * Md[k]  # Aqui se peude ajustar

# %%
# Construcción de los parámetros
A = dict(zip(list(Camiones), autonomias))
E = dict(zip(list(Camiones), emisiones))
Ckm = dict(zip(list(Camiones), costos_km))
Cc = dict(zip(list(Camiones), precios))
Q = dict(zip(list(Camiones), capacidades))
Do = [
    28,
    366,
    644,
    101,
    392,
    306,
    356,
    171,
    360,
    363,
]  # distancias a los origenes en km

Dd = [546, 205, 41, 559, 304, 244, 35, 80, 59, 197]  # distancias a los destinos en km

R = {
    1: 48,
    2: 57,
    3: 81,
    4: 33,
    5: 111,
    6: 102,
    7: 100,
    8: 29,
    9: 105,
    10: 106,
}  # el origen que está más cerca ofrece menos

for i in R.keys(): R[i] = 1 * R[i]  # Aqui se puede ajustar

Bo = {(i, o): tpo_en_bloques1[o - 1] for o in Origenes for i in Camiones}
Bd = {(i, d): tpo_en_bloques2[d - 1] for d in Destinos for i in Camiones}
print("Parametros construidos")

# ------------ Generar el modelo ------------
model = Model("Entrega Proyecto")
model.setParam("TimeLimit", 30 * 60)

# ------------ Instanciar variables de decisión ------------
U = model.addVars(Bloques, Dias, vtype=GRB.INTEGER, name="U_bt")
X = model.addVars(Camiones, Bloques, Dias, Destinos, vtype=GRB.INTEGER, name="X_ibtd")
W = model.addVars(Camiones, Bloques, Dias, Origenes, vtype=GRB.INTEGER, name="W_ibto")
M = model.addVars(Bloques, Dias, Origenes, vtype=GRB.INTEGER, name="M_bto")
Y = model.addVars(Camiones, Bloques, Dias, Origenes, vtype=GRB.BINARY, name="Y_ibto")
Z = model.addVars(Camiones, Bloques, Dias, Destinos, vtype=GRB.BINARY, name="Z_ibtd")
D = model.addVars(Bloques, Dias, vtype=GRB.INTEGER, name="D_bt") # desechos de madera al final de un bloque de cierto día

alpha = model.addVars(Camiones, Bloques, Dias, vtype=GRB.BINARY, name="alpha_ibt")
beta = model.addVars(Camiones, vtype=GRB.BINARY, name="beta_i")

model.update()
print("Variables de decisión instanciadas")

model.addConstrs(
    (
        bigM * (1 - Y[i, b, t, o]) + A[i]
        >= Do[o - 1]  # ojo porque la posicion de la lista va desde el 0
        for i in Camiones
        for t in Dias
        for b in Bloques
        for o in Origenes
    ),
    name="R1a",
)
model.addConstrs(
    (
        bigM * (1 - Z[i, b, t, d]) + A[i] >= Dd[d - 1]
        for i in Camiones
        for t in Dias
        for b in Bloques
        for d in Destinos
    ),
    name="R1b",
)
print("R1 agregada")

Bloques_para_b0_bd = {}
Bloques_para_b0_bo = {}
for i in Camiones:
    for b1 in Bloques[:-2]:
        for d in Destinos:
            final = b1 + 2 * Bd[(i, d)]
            if final > 48:
                Bloques_para_b0_bd[(b1, i, d)] = Bloques[b1 + 1 :]
            else:  # No estoy seguro de estos indices
                Bloques_para_b0_bd[(b1, i, d)] = Bloques[b1 + 1 : final]
        for o in Origenes:
            final = b1 + 2 * Bo[(i, o)]
            if final > 48:
                Bloques_para_b0_bo[(b1, i, o)] = Bloques[b1 + 1 :]
            else:
                Bloques_para_b0_bo[(b1, i, o)] = Bloques[b1 + 1 : final]
model.addConstrs(
    (
        alpha[i, b0, t] >= Z[i, b1, t, d]
        for i in Camiones
        for t in Dias
        for d in Destinos
        for b1 in Bloques[:-2]
        for b0 in Bloques_para_b0_bd[(b1, i, d)]
    ),
    name="R2a",
)
model.addConstrs(
    (
        alpha[i, b0, t] >= Y[i, b1, t, o]
        for i in Camiones
        for t in Dias
        for o in Origenes
        for b1 in Bloques[:-2]
        for b0 in Bloques_para_b0_bo[(b1, i, o)]
    ),
    name="R2b",
)
print("R2 agregada")

model.addConstrs(
    (
        b + 2 * Bd[i, d] <= 48 + bigM * (1 - Z[i, b, t, d])
        for i in Camiones
        for d in Destinos
        for b in Bloques
        for t in Dias
    ),
    name="R3a",
)
model.addConstrs(
    (
        b + 2 * Bo[i, o] <= 48 + bigM * (1 - Y[i, b, t, o])
        for i in Camiones
        for b in Bloques
        for t in Dias
        for o in Origenes
    ),
    name="R3b",
)
model.addConstrs(
    (
        bigM * Y[i, b - Bo[i, o], t, o] >= W[i, b, t, o]
        for i in Camiones
        for o in Origenes
        for b in Bloques[Bo[i, o] + 1 :]
        for t in Dias
    ),
    name="R3c",
)
print("R3 agregada")

# -------------------- restricción cambiada
model.addConstrs(
    (
        U[1, t + 1] == U[48, t] 
        # for b in Bloques
        for t in Dias[:-1]
    ),
    name="R4a",
)

# -------------------- restricción cambiada
Camiones_r4b_bo = lambda b, o: [i for i in Camiones if b - 2*Bo[(i, o)] >= 1]
Camiones_r4b_bd = lambda b, d: [i for i in Camiones if b + 2*Bd[(i, d)] <= 48]
r4b_sum1 = lambda b, t: quicksum(
    W[i, b - Bo[(i, o)], t, o] for o in Origenes for i in Camiones_r4b_bo(b, o)
)
r4b_sum2 = lambda b, t: quicksum(
    X[i, b + Bd[(i, d)], t, d] for d in Destinos for i in Camiones_r4b_bd(b, d)
)
model.addConstrs(
    (
        U[b + 1, t] == U[b, t] + r4b_sum1(b, t) - r4b_sum2(b, t) - D[b, t]
        for b in Bloques[:-1]
        for t in Dias
    ),
    name="R4b",
)

# -------------------- restricción eliminada

# ----------------------------------- restricción creada
r4c_sum1 = lambda t: quicksum(
    W[i, b, t, o] for o in Origenes for i in Camiones for b in Bloques
)
r4c_sum2 = lambda t: quicksum(Md[d, t] for d in Destinos)
model.addConstrs(
    (
        U[48, t] == r4c_sum1(t) - r4c_sum2(t) - D[48, t]
        for t in Dias[:-1]
    ),
    name="R4c",
)


# ---------------------------- restricción eliminada

# No se realizan despachos de pedidos en el primer bloque
model.addConstrs(
    (Z[i, 1, t, d] == 0 for d in Destinos for i in Camiones for t in Dias),
    name="R5b",
)
print("R5 agregada")


r6_sum1 = lambda i, b, t: quicksum(Z[i, b, t, d] for d in Destinos)  # for j in Pedidos
r6_sum2 = lambda i, b, t: quicksum(Y[i, b, t, o] for o in Origenes)
model.addConstrs(
    (
        alpha[i, b, t] + r6_sum1(i, b, t) + r6_sum2(i, b, t) <= 1
        for i in Camiones
        for b in Bloques
        for t in Dias
    ),
    name="R6",
)
print("R6 agregada")


model.addConstrs(
    (
        X[i, b, t, d] <= Q[i]
        for i in Camiones
        for b in Bloques
        for t in Dias
        for d in Destinos
    ),
    name="R7a",
)
model.addConstrs(
    (
        W[i, b, t, o] <= Q[i]
        for i in Camiones
        for t in Dias
        for b in Bloques
        for o in Origenes
    ),
    name="R7b",
)
print("R7 agregada")


# ---------------------------------- restricción cambiada
r8_sum1 = lambda i, b, t: quicksum(
    Z[i, b, t, d] * Dd[d - 1] for d in Destinos  
)
r8_sum2 = lambda i, b, t: quicksum(Y[i, b, t, o] * Do[o - 1] for o in Origenes)
r8_sum3 = lambda t, b: quicksum(
    2 * (Ckm[i] + E[i] * Ce) * (r8_sum1(i, b, t) + r8_sum2(i, b, t))
    for i in Camiones
)
model.addConstr(
    quicksum(beta[i] * Cc[i] for i in Camiones) + quicksum(U[b, t] * Cq + r8_sum3(t, b) for t in Dias for b in Bloques) <= G,
    name="R8",
)
print("R8 agregada")


model.addConstrs((U[b, t] <= Qmax for b in Bloques for t in Dias), name="R9")
print("R9 agregada")


# -------------------------------- restricción eliminada


# -------------------------------- restricción eliminada
# -------------------------------- restricción eliminada

# ------------------------------------------ restricción cambiada
sumc = lambda i, b, t: quicksum(alpha[i, b1, t] for b1 in Bloques[b + 1: b + 2 * Bd[i, d]])
model.addConstrs(
    (
        2 * Bd[i, d] * Z[i, b, t, d] <= sumc(i, b, t)
        for i in Camiones
        for t in Dias
        for d in Destinos
        for b in range(1, (48 - 2 * Bd[i, d]))
    ),
    name="R11c",
)

# ------------------------------ restricción arreglada: tenía for d in Destinos en vez de for o in Origenes
# ------------------------------------------ restricción cambiada
sumd = lambda i, b, t: quicksum(alpha[i, b1, t] for b1 in Bloques[b + 1 : b + 2 * Bd[i, d]])
model.addConstrs(
    (
        2 * Bo[i, o] * Z[i, b, t, o] <= sumd(i, b, t)
        for i in Camiones
        for t in Dias
        for o in Origenes
        for b in range(1, (48 - 2 * Bo[i, o]))
    ),
    name="R11d",
)
print("R11 agregada")


model.addConstrs(
    (
        quicksum(alpha[i, b, t] for b in Bloques for t in Dias) <= bigM * beta[i]
        for i in Camiones
    ),
    name="R12",
)
print("R12 agregada")



model.addConstrs(
    (
        M[b, t, o]
        == R[o] + M[b - 1, t, o] - quicksum(W[i, b - 1, t, o] for i in Camiones)
        for b in Bloques[1:]  # b ∈{2,…,48}
        for o in Origenes
        for t in Dias
    ),
    name="R13",
)
print("R13 agregada")


model.addConstrs(
    (
        bigM * Y[i, b - Bo[i, o], t, o] >= W[i, b, t, o]
        for i in Camiones
        for o in Origenes
        for t in Dias
        for b in range(Bo[i, o] + 1, 48)
        
    ),
    name="R14a",
)

model.addConstrs(
    (
        Y[i, b - Bo[i, o], t, o] <= W[i, b, t, o]
        for i in Camiones
        for o in Origenes
        for t in Dias
        for b in range(Bo[i, o] + 1, 48)
    ),
    name="R14b",
)

model.addConstrs(
    (
        bigM * Z[i, b - Bd[i, d], t, d] >= X[i, b, t, d]
        for i in Camiones
        for d in Destinos
        for t in Dias
        for b in range(Bd[i, d] + 1, 48)
    ),
    name="R14c",
)

model.addConstrs(
    (
        Z[i, b - Bd[i, d], t, d] <= X[i, b, t, d]
        for i in Camiones
        for d in Destinos
        for t in Dias
        for b in range(Bd[i, d] + 1, 48)
    ),
    name="R14d",
)

model.addConstrs(
    (
        W[i, b2, t, o] <= bigM * (1 - Y[i, b1, t, o])
        for i in Camiones
        for t in Dias
        for o in Origenes
        for b1 in range(1, 48 - 2 * Bo[i, o])
        for b2 in range(b1, b1 + Bo[i, o])

    ),
    name="R14e"
)

model.addConstrs(
    (
        X[i, b2, t, d] <= bigM * (1 - Z[i, b1, t, d])
        for i in Camiones
        for t in Dias
        for d in Destinos
        for b1 in range(1, 48 - 2 * Bd[i, d])
        for b2 in range(b1, b1 + Bd[i, d])

    ),
    name="R14f"
)


print("R14 agregada")


model.addConstrs((M[1, 1, o] == R[o] for o in Origenes), name="R15")
print("R15 agregada")


model.addConstrs(
    (alpha[i, 1, t] == 0 for i in Camiones for t in Dias),
    name="R16",
)
print("R16 agregada")


model.addConstrs(
    (
        bigM * alpha[i, b, t] >= W[i, b, t, o]
        for i in Camiones
        for t in Dias
        for b in Bloques
        for o in Origenes
    ),
    name="R17a",
)

model.addConstrs(
    (
        bigM * alpha[i, b, t] >= X[i, b, t, d]
        for i in Camiones
        for t in Dias
        for b in Bloques
        for d in Destinos
    ),
    name="R17b",
)

print("R17 agregada")


model.addConstrs(
    (
        Md[d, t] == quicksum(X[i, b, t, d] for b in Bloques[2:48] for i in Camiones)
            for t in Dias
            for d in Destinos
    ),
    name="R18",
)

print("R18 agregada")


# # --------------------------------------------------- restricción creada
# model.addConstrs(
#     (
#         X[i, b, t, d] == 0
#             for i in Camiones
#             for t in Dias
#             for d in Destinos
#             for b in Bloques[: Bd[i, d]]
#     ),
#     name="R19a",
# )

# # --------------------------------------------------- restricción creada
# model.addConstrs(
#     (
#         W[i, b, t, o] == 0
#             for i in Camiones
#             for t in Dias
#             for o in Origenes
#             for b in Bloques[: Bd[i, d]]
#     ),
#     name="R19b",
# )

# print("R19 agregada")

model.addConstrs(
    (
        X[i, b, t, d] <= bigM * Z[i, b - Bd[i, d], t, d]
            for i in Camiones
            for t in Dias
            for d in Destinos
            for b in Bloques[Bd[i, d] + 1 :]
    ),
    name='R20a'
)

model.addConstrs(
    (
        W[i, b, t, o] <= bigM * Y[i, b - Bo[i, o], t, o]
            for i in Camiones
            for t in Dias
            for o in Origenes
            for b in Bloques[Bo[i, o] + 1 :]
    ),
    name='R20b'
)
print("R20 agregada")


# ------------ Función objetivo ------------

fo_sum1 = lambda t, b, i: quicksum(
    Z[i, b, t, d] * Dd[d - 1] for d in Destinos  
)
fo_sum2 = lambda t, b, i: quicksum(Y[i, b, t, o] * Do[o - 1] for o in Origenes)
objetivo = quicksum(
    2 * E[i] * (fo_sum1(t, b, i) + fo_sum2(t, b, i))
    for t in Dias
    for b in Bloques
    for i in Camiones
)

model.setObjective(objetivo, GRB.MINIMIZE)

print("Optimizando...")
model.optimize()

# Guardamos las soluciones en archivo.sol
for i in range(model.SolCount):
    model.Params.SolutionNumber = i
    model.write(f"{i}.sol")
    c0 = model.getConstrByName("R8")
    print(i, c0)
    print(f'La holgura presupuestaria de la solución {i} es {c0.getAttr("slack")}')

print("\n" + "-" * 10 + " Manejo Soluciones " + "-" * 10)
print(f"El valor objetivo es de: {model.ObjVal}")
for camion in Camiones:
    if beta[camion].x != 0:
        if E[camion] != 0:
            tipo = "diesel"
        else:
            tipo = "eléctrico"
        print(f"Se compra el camión {str(camion)} de tipo {tipo}")
# Out:
# Parametros construidos
# Set parameter TimeLimit to value 1800
# Variables de decisión instanciadas
# R1 agregada
# R2 agregada
# R3 agregada
# R5 agregada
# R6 agregada
# R7 agregada
# R8 agregada
# R9 agregada
# R11 agregada
# R12 agregada
# R13 agregada
# R14 agregada
# R15 agregada
# R16 agregada
# R17 agregada
# R18 agregada
# R20 agregada
# Optimizando...
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (linux64)
#
# CPU model: AMD Ryzen 5 2500U with Radeon Vega Mobile Gfx, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1747310 rows, 160336 columns and 4052663 nonzeros
# Model fingerprint: 0xb36b8719
# Variable types: 0 continuous, 160336 integer (80656 binary)
# Coefficient statistics:
#   Matrix range     [6e-03, 1e+05]
#   Objective range  [1e-01, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+05]
# Presolve removed 1645875 rows and 125115 columns (presolve time = 5s) ...
# Presolve removed 1646400 rows and 125310 columns (presolve time = 10s) ...
# Presolve removed 1652306 rows and 125326 columns
# Presolve time: 13.53s
# Presolved: 95004 rows, 35010 columns, 330948 nonzeros
# Variable types: 0 continuous, 35010 integer (13094 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing first log only...
#
#
#
# Root relaxation: interrupted, 0 iterations, 0.31 seconds (0.08 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                       0.0000000    0.00000  0.00%     -   17s
#
# Explored 1 nodes (0 simplex iterations) in 17.97 seconds (11.48 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# 0 <gurobi.Constr R8>
# La holgura presupuestaria de la solución 0 es 7.984540000000038
#
# ---------- Manejo Soluciones ----------
# El valor objetivo es de: 0.0
# Se compra el camión 1 de tipo diesel
# Se compra el camión 9 de tipo eléctrico
# Se compra el camión 10 de tipo eléctrico
# Se compra el camión 12 de tipo eléctrico
# Se compra el camión 13 de tipo eléctrico

# %%
for v in model.getVars():
    if v.X > 0.5 and v.varName[0] in ["Y", "Z"]:
        print(v.varName, v.X)
# Out:
# Y_ibto[9,2,1,5] 1.0
# Y_ibto[9,2,2,5] 1.0
# Y_ibto[9,2,3,5] 1.0
# Y_ibto[9,2,4,5] 1.0
# Y_ibto[9,2,5,5] 1.0
# Y_ibto[9,3,1,2] 1.0
# Y_ibto[9,3,2,2] 1.0
# Y_ibto[9,3,3,2] 1.0
# Y_ibto[9,3,4,2] 1.0
# Y_ibto[9,3,5,2] 1.0
# Y_ibto[10,1,2,4] 1.0
# Y_ibto[10,1,3,4] 1.0
# Y_ibto[10,1,4,4] 1.0
# Y_ibto[10,2,1,4] 1.0
# Y_ibto[10,2,5,4] 1.0
# Y_ibto[12,1,1,4] 1.0
# Y_ibto[12,1,2,4] 1.0
# Y_ibto[12,1,3,4] 1.0
# Y_ibto[12,1,4,4] 1.0
# Y_ibto[12,1,5,4] 1.0
# Y_ibto[12,2,1,8] 1.0
# Y_ibto[12,2,2,8] 1.0
# Y_ibto[12,2,3,8] 1.0
# Y_ibto[12,2,4,8] 1.0
# Y_ibto[12,2,5,8] 1.0
# Y_ibto[12,17,1,8] 1.0
# Y_ibto[12,17,2,8] 1.0
# Y_ibto[12,17,3,8] 1.0
# Y_ibto[12,17,4,8] 1.0
# Y_ibto[12,17,5,8] 1.0
# Y_ibto[13,2,1,5] 1.0
# Y_ibto[13,2,2,5] 1.0
# Y_ibto[13,2,3,5] 1.0
# Y_ibto[13,2,4,5] 1.0
# Y_ibto[13,2,5,5] 1.0
# Y_ibto[13,3,1,2] 1.0
# Y_ibto[13,3,2,2] 1.0
# Y_ibto[13,3,3,2] 1.0
# Y_ibto[13,3,4,2] 1.0
# Y_ibto[13,3,5,2] 1.0
# Z_ibtd[10,12,1,3] 1.0
# Z_ibtd[10,12,2,3] 1.0
# Z_ibtd[10,12,3,3] 1.0
# Z_ibtd[10,12,4,3] 1.0
# Z_ibtd[10,12,5,3] 1.0
# Z_ibtd[10,26,1,9] 1.0
# Z_ibtd[10,26,2,9] 1.0
# Z_ibtd[10,26,3,9] 1.0
# Z_ibtd[10,26,4,9] 1.0
# Z_ibtd[10,26,5,9] 1.0
# Z_ibtd[10,27,1,7] 1.0
# Z_ibtd[10,27,2,7] 1.0
# Z_ibtd[10,27,3,7] 1.0
# Z_ibtd[10,27,4,7] 1.0
# Z_ibtd[10,27,5,7] 1.0

# %%
for v in model.getVars():
    if v.X > 0.5 and v.varName[0] in [ "W", "X", "a"]:
        print(v.varName, v.X)
# Out:
# X_ibtd[1,3,6,8] 54.0
# X_ibtd[1,3,8,8] 60.0
# X_ibtd[1,3,9,2] 79.0
# X_ibtd[1,5,3,2] 62.0
# X_ibtd[1,5,4,6] 71.0
# X_ibtd[1,5,4,10] 56.0
# X_ibtd[1,5,9,10] 64.0
# X_ibtd[1,6,7,10] 60.0
# X_ibtd[1,7,2,6] 63.0
# X_ibtd[5,3,2,8] 82.0
# X_ibtd[5,3,3,8] 67.0
# X_ibtd[5,3,7,8] 90.0
# X_ibtd[5,4,1,6] 64.0
# X_ibtd[5,4,7,6] 67.0
# X_ibtd[5,5,4,2] 71.0
# X_ibtd[5,5,8,10] 65.0
# X_ibtd[5,6,3,6] 78.0
# X_ibtd[15,25,5,3] 88.0
# X_ibtd[15,34,5,9] 74.0
# X_ibtd[15,34,10,3] 75.0
# X_ibtd[15,36,7,3] 64.0
# X_ibtd[15,38,6,7] 62.0
# X_ibtd[15,38,8,3] 63.0
# X_ibtd[15,40,2,7] 64.0
# X_ibtd[15,41,4,3] 67.0
# X_ibtd[15,42,3,9] 50.0
# X_ibtd[15,44,5,7] 84.0
# X_ibtd[15,44,6,9] 52.0
# X_ibtd[15,45,1,3] 51.0
# X_ibtd[15,45,10,7] 86.0
# X_ibtd[15,47,3,7] 87.0
# X_ibtd[15,47,7,7] 79.0
# X_ibtd[15,47,8,7] 90.0
# X_ibtd[15,47,9,7] 64.0
# X_ibtd[16,3,1,8] 56.0
# X_ibtd[16,3,2,2] 77.0
# X_ibtd[16,3,2,10] 51.0
# X_ibtd[16,3,4,8] 55.0
# X_ibtd[16,3,5,8] 57.0
# X_ibtd[16,3,5,10] 55.0
# X_ibtd[16,3,6,2] 68.0
# X_ibtd[16,3,7,2] 55.0
# X_ibtd[16,3,9,8] 70.0
# X_ibtd[16,3,10,8] 70.0
# X_ibtd[16,4,5,2] 72.0
# X_ibtd[16,4,5,6] 79.0
# X_ibtd[16,4,8,2] 72.0
# X_ibtd[16,4,8,6] 88.0
# X_ibtd[16,4,10,2] 70.0
# X_ibtd[16,4,10,10] 81.0
# X_ibtd[16,5,10,6] 63.0
# X_ibtd[16,6,1,2] 57.0
# X_ibtd[16,6,1,10] 55.0
# X_ibtd[16,6,3,10] 60.0
# X_ibtd[16,6,6,6] 86.0
# X_ibtd[16,6,6,10] 64.0
# X_ibtd[16,7,9,6] 85.0
# X_ibtd[16,9,1,5] 65.0
# X_ibtd[16,9,2,5] 55.0
# X_ibtd[16,9,3,5] 64.0
# X_ibtd[16,9,4,5] 63.0
# X_ibtd[16,9,5,5] 52.0
# X_ibtd[16,9,6,5] 73.0
# X_ibtd[16,9,7,5] 74.0
# X_ibtd[16,9,8,5] 54.0
# X_ibtd[16,9,9,5] 90.0
# X_ibtd[16,9,10,5] 54.0
# X_ibtd[16,16,1,1] 90.0
# X_ibtd[16,16,1,4] 67.0
# X_ibtd[16,16,2,1] 87.0
# X_ibtd[16,16,2,4] 51.0
# X_ibtd[16,16,3,1] 85.0
# X_ibtd[16,16,3,4] 76.0
# X_ibtd[16,16,4,1] 77.0
# X_ibtd[16,16,4,4] 59.0
# X_ibtd[16,16,5,1] 72.0
# X_ibtd[16,16,5,4] 66.0
# X_ibtd[16,16,6,1] 85.0
# X_ibtd[16,16,6,4] 89.0
# X_ibtd[16,16,7,1] 68.0
# X_ibtd[16,16,7,4] 56.0
# X_ibtd[16,16,8,1] 73.0
# X_ibtd[16,16,8,4] 67.0
# X_ibtd[16,16,9,1] 60.0
# X_ibtd[16,16,9,4] 67.0
# X_ibtd[16,16,10,1] 52.0
# X_ibtd[16,16,10,4] 67.0
# X_ibtd[16,21,6,3] 90.0
# X_ibtd[16,29,7,9] 73.0
# X_ibtd[16,29,9,3] 74.0
# X_ibtd[16,31,2,9] 88.0
# X_ibtd[16,32,1,9] 84.0
# X_ibtd[16,32,4,9] 74.0
# X_ibtd[16,35,3,3] 84.0
# X_ibtd[16,37,10,9] 63.0
# X_ibtd[16,39,9,9] 53.0
# X_ibtd[16,43,8,9] 84.0
# X_ibtd[16,46,2,3] 52.0
# X_ibtd[16,47,1,7] 58.0
# X_ibtd[16,47,4,7] 56.0
# W_ibto[1,2,2,2] 120.0
# W_ibto[1,2,2,3] 120.0
# W_ibto[1,2,2,4] 120.0
# W_ibto[1,2,2,5] 120.0
# W_ibto[1,2,2,6] 120.0
# W_ibto[1,2,2,7] 120.0
# W_ibto[1,2,2,8] 120.0
# W_ibto[1,2,2,9] 120.0
# W_ibto[1,2,2,10] 120.0
# W_ibto[1,2,3,2] 120.0
# W_ibto[1,2,3,3] 120.0
# W_ibto[1,2,3,4] 120.0
# W_ibto[1,2,3,5] 120.0
# W_ibto[1,2,3,6] 120.0
# W_ibto[1,2,3,7] 120.0
# W_ibto[1,2,3,8] 120.0
# W_ibto[1,2,3,9] 120.0
# W_ibto[1,2,3,10] 120.0
# W_ibto[1,2,4,2] 120.0
# W_ibto[1,2,4,3] 120.0
# W_ibto[1,2,4,4] 120.0
# W_ibto[1,2,4,5] 120.0
# W_ibto[1,2,4,6] 120.0
# W_ibto[1,2,4,7] 120.0
# W_ibto[1,2,4,8] 120.0
# W_ibto[1,2,4,9] 120.0
# W_ibto[1,2,4,10] 120.0
# W_ibto[1,2,5,2] 120.0
# W_ibto[1,2,5,3] 120.0
# W_ibto[1,2,5,4] 120.0
# W_ibto[1,2,5,5] 120.0
# W_ibto[1,2,5,6] 120.0
# W_ibto[1,2,5,7] 120.0
# W_ibto[1,2,5,8] 120.0
# W_ibto[1,2,5,9] 120.0
# W_ibto[1,2,5,10] 120.0
# W_ibto[1,2,6,2] 120.0
# W_ibto[1,2,6,3] 120.0
# W_ibto[1,2,6,4] 120.0
# W_ibto[1,2,6,5] 120.0
# W_ibto[1,2,6,6] 120.0
# W_ibto[1,2,6,7] 120.0
# W_ibto[1,2,6,8] 120.0
# W_ibto[1,2,6,9] 120.0
# W_ibto[1,2,6,10] 120.0
# W_ibto[1,2,7,2] 120.0
# W_ibto[1,2,7,3] 120.0
# W_ibto[1,2,7,4] 120.0
# W_ibto[1,2,7,5] 120.0
# W_ibto[1,2,7,6] 120.0
# W_ibto[1,2,7,7] 120.0
# W_ibto[1,2,7,8] 120.0
# W_ibto[1,2,7,9] 120.0
# W_ibto[1,2,7,10] 120.0
# W_ibto[1,2,8,2] 120.0
# W_ibto[1,2,8,3] 120.0
# W_ibto[1,2,8,4] 120.0
# W_ibto[1,2,8,5] 120.0
# W_ibto[1,2,8,6] 120.0
# W_ibto[1,2,8,7] 120.0
# W_ibto[1,2,8,8] 120.0
# W_ibto[1,2,8,9] 120.0
# W_ibto[1,2,8,10] 120.0
# W_ibto[1,2,9,2] 120.0
# W_ibto[1,2,9,3] 120.0
# W_ibto[1,2,9,4] 120.0
# W_ibto[1,2,9,5] 120.0
# W_ibto[1,2,9,6] 120.0
# W_ibto[1,2,9,7] 120.0
# W_ibto[1,2,9,8] 120.0
# W_ibto[1,2,9,9] 120.0
# W_ibto[1,2,9,10] 120.0
# W_ibto[1,2,10,2] 120.0
# W_ibto[1,2,10,3] 120.0
# W_ibto[1,2,10,4] 120.0
# W_ibto[1,2,10,5] 120.0
# W_ibto[1,2,10,6] 120.0
# W_ibto[1,2,10,7] 120.0
# W_ibto[1,2,10,8] 120.0
# W_ibto[1,2,10,9] 120.0
# W_ibto[1,2,10,10] 120.0
# W_ibto[1,5,1,10] 120.0
# W_ibto[1,19,1,3] 120.0
# W_ibto[5,2,2,2] 120.0
# W_ibto[5,2,2,3] 120.0
# W_ibto[5,2,2,4] 120.0
# W_ibto[5,2,2,5] 120.0
# W_ibto[5,2,2,6] 120.0
# W_ibto[5,2,2,7] 120.0
# W_ibto[5,2,2,8] 120.0
# W_ibto[5,2,2,9] 120.0
# W_ibto[5,2,2,10] 120.0
# W_ibto[5,2,3,2] 120.0
# W_ibto[5,2,3,3] 120.0
# W_ibto[5,2,3,4] 120.0
# W_ibto[5,2,3,5] 120.0
# W_ibto[5,2,3,6] 120.0
# W_ibto[5,2,3,7] 120.0
# W_ibto[5,2,3,8] 120.0
# W_ibto[5,2,3,9] 120.0
# W_ibto[5,2,3,10] 120.0
# W_ibto[5,2,4,2] 120.0
# W_ibto[5,2,4,3] 120.0
# W_ibto[5,2,4,4] 120.0
# W_ibto[5,2,4,5] 120.0
# W_ibto[5,2,4,6] 120.0
# W_ibto[5,2,4,7] 120.0
# W_ibto[5,2,4,8] 120.0
# W_ibto[5,2,4,9] 120.0
# W_ibto[5,2,4,10] 120.0
# W_ibto[5,2,5,2] 120.0
# W_ibto[5,2,5,3] 120.0
# W_ibto[5,2,5,4] 120.0
# W_ibto[5,2,5,5] 120.0
# W_ibto[5,2,5,6] 120.0
# W_ibto[5,2,5,7] 120.0
# W_ibto[5,2,5,8] 120.0
# W_ibto[5,2,5,9] 120.0
# W_ibto[5,2,5,10] 120.0
# W_ibto[5,2,6,2] 120.0
# W_ibto[5,2,6,3] 120.0
# W_ibto[5,2,6,4] 120.0
# W_ibto[5,2,6,5] 120.0
# W_ibto[5,2,6,6] 120.0
# W_ibto[5,2,6,7] 120.0
# W_ibto[5,2,6,8] 120.0
# W_ibto[5,2,6,9] 120.0
# W_ibto[5,2,6,10] 120.0
# W_ibto[5,2,7,2] 120.0
# W_ibto[5,2,7,3] 120.0
# W_ibto[5,2,7,4] 120.0
# W_ibto[5,2,7,5] 120.0
# W_ibto[5,2,7,6] 120.0
# W_ibto[5,2,7,7] 120.0
# W_ibto[5,2,7,8] 120.0
# W_ibto[5,2,7,9] 120.0
# W_ibto[5,2,7,10] 120.0
# W_ibto[5,2,8,2] 120.0
# W_ibto[5,2,8,3] 120.0
# W_ibto[5,2,8,4] 120.0
# W_ibto[5,2,8,5] 120.0
# W_ibto[5,2,8,6] 120.0
# W_ibto[5,2,8,7] 120.0
# W_ibto[5,2,8,8] 120.0
# W_ibto[5,2,8,9] 120.0
# W_ibto[5,2,8,10] 120.0
# W_ibto[5,2,9,2] 120.0
# W_ibto[5,2,9,3] 120.0
# W_ibto[5,2,9,4] 120.0
# W_ibto[5,2,9,5] 120.0
# W_ibto[5,2,9,6] 120.0
# W_ibto[5,2,9,7] 120.0
# W_ibto[5,2,9,8] 120.0
# W_ibto[5,2,9,9] 120.0
# W_ibto[5,2,9,10] 120.0
# W_ibto[5,2,10,2] 120.0
# W_ibto[5,2,10,3] 120.0
# W_ibto[5,2,10,4] 120.0
# W_ibto[5,2,10,5] 120.0
# W_ibto[5,2,10,6] 120.0
# W_ibto[5,2,10,7] 120.0
# W_ibto[5,2,10,8] 120.0
# W_ibto[5,2,10,9] 120.0
# W_ibto[5,2,10,10] 120.0
# W_ibto[15,6,2,4] 1.0
# W_ibto[15,18,6,1] 90.0
# W_ibto[15,26,7,1] 73.0
# W_ibto[15,26,9,1] 74.0
# W_ibto[15,28,2,1] 120.0
# W_ibto[15,29,1,1] 120.0
# W_ibto[15,29,4,1] 120.0
# W_ibto[15,32,3,1] 120.0
# W_ibto[15,34,10,1] 120.0
# W_ibto[15,36,9,1] 53.0
# W_ibto[15,38,8,4] 84.0
# W_ibto[15,43,2,1] 52.0
# W_ibto[15,44,6,1] 1.0
# W_ibto[15,45,1,1] 120.0
# W_ibto[15,45,4,1] 120.0
# W_ibto[16,2,2,1] 183.0
# W_ibto[16,2,2,2] 183.0
# W_ibto[16,2,2,3] 183.0
# W_ibto[16,2,2,5] 183.0
# W_ibto[16,2,2,6] 183.0
# W_ibto[16,2,2,7] 183.0
# W_ibto[16,2,2,9] 183.0
# W_ibto[16,2,2,10] 183.0
# W_ibto[16,2,3,1] 183.0
# W_ibto[16,2,3,2] 183.0
# W_ibto[16,2,3,3] 183.0
# W_ibto[16,2,3,5] 183.0
# W_ibto[16,2,3,6] 183.0
# W_ibto[16,2,3,7] 183.0
# W_ibto[16,2,3,9] 183.0
# W_ibto[16,2,3,10] 183.0
# W_ibto[16,2,4,1] 183.0
# W_ibto[16,2,4,2] 183.0
# W_ibto[16,2,4,3] 183.0
# W_ibto[16,2,4,5] 183.0
# W_ibto[16,2,4,6] 183.0
# W_ibto[16,2,4,7] 183.0
# W_ibto[16,2,4,9] 183.0
# W_ibto[16,2,4,10] 183.0
# W_ibto[16,2,5,1] 183.0
# W_ibto[16,2,5,2] 183.0
# W_ibto[16,2,5,3] 183.0
# W_ibto[16,2,5,5] 183.0
# W_ibto[16,2,5,6] 183.0
# W_ibto[16,2,5,7] 183.0
# W_ibto[16,2,5,9] 183.0
# W_ibto[16,2,5,10] 183.0
# W_ibto[16,2,6,1] 183.0
# W_ibto[16,2,6,2] 183.0
# W_ibto[16,2,6,3] 183.0
# W_ibto[16,2,6,5] 183.0
# W_ibto[16,2,6,6] 183.0
# W_ibto[16,2,6,7] 183.0
# W_ibto[16,2,6,9] 183.0
# W_ibto[16,2,6,10] 183.0
# W_ibto[16,2,7,1] 183.0
# W_ibto[16,2,7,2] 183.0
# W_ibto[16,2,7,3] 183.0
# W_ibto[16,2,7,5] 183.0
# W_ibto[16,2,7,6] 183.0
# W_ibto[16,2,7,7] 183.0
# W_ibto[16,2,7,9] 183.0
# W_ibto[16,2,7,10] 183.0
# W_ibto[16,2,9,1] 183.0
# W_ibto[16,2,9,2] 183.0
# W_ibto[16,2,9,3] 183.0
# W_ibto[16,2,9,5] 183.0
# W_ibto[16,2,9,6] 183.0
# W_ibto[16,2,9,7] 183.0
# W_ibto[16,2,9,9] 183.0
# W_ibto[16,2,9,10] 183.0
# W_ibto[16,2,10,1] 183.0
# W_ibto[16,2,10,2] 183.0
# W_ibto[16,2,10,3] 183.0
# W_ibto[16,2,10,5] 183.0
# W_ibto[16,2,10,6] 183.0
# W_ibto[16,2,10,7] 183.0
# W_ibto[16,2,10,9] 183.0
# W_ibto[16,2,10,10] 183.0
# W_ibto[16,3,8,1] 1.0
# W_ibto[16,6,8,8] 1.0
# W_ibto[16,9,10,1] 1.0
# W_ibto[16,13,8,1] 183.0
# W_ibto[16,16,3,1] 183.0
# W_ibto[16,19,1,3] 183.0
# W_ibto[16,20,5,4] 183.0
# W_ibto[16,31,5,1] 102.0
# W_ibto[16,31,10,1] 75.0
# W_ibto[16,32,5,4] 183.0
# W_ibto[16,33,7,1] 64.0
# W_ibto[16,33,8,4] 63.0
# W_ibto[16,34,6,4] 183.0
# W_ibto[16,38,2,1] 64.0
# W_ibto[16,38,4,1] 183.0
# W_ibto[16,38,8,1] 1.0
# W_ibto[16,39,1,1] 183.0
# W_ibto[16,39,3,1] 50.0
# W_ibto[16,39,9,1] 183.0
# W_ibto[16,40,1,4] 183.0
# W_ibto[16,41,4,1] 183.0
# W_ibto[16,41,6,1] 183.0
# W_ibto[16,41,7,8] 79.0
# W_ibto[16,42,2,1] 183.0
# W_ibto[16,42,5,1] 183.0
# W_ibto[16,42,6,4] 183.0
# W_ibto[16,43,8,4] 183.0
# W_ibto[16,43,10,1] 86.0
# W_ibto[16,45,3,1] 87.0
# W_ibto[16,45,9,1] 64.0
# alpha_ibt[1,2,1] 1.0
# alpha_ibt[1,2,2] 1.0
# alpha_ibt[1,2,3] 1.0
# alpha_ibt[1,2,4] 1.0
# alpha_ibt[1,2,5] 1.0
# alpha_ibt[1,2,6] 1.0
# alpha_ibt[1,2,7] 1.0
# alpha_ibt[1,2,8] 1.0
# alpha_ibt[1,2,9] 1.0
# alpha_ibt[1,2,10] 1.0
# alpha_ibt[1,3,1] 1.0
# alpha_ibt[1,3,2] 1.0
# alpha_ibt[1,3,3] 1.0
# alpha_ibt[1,3,4] 1.0
# alpha_ibt[1,3,5] 1.0
# alpha_ibt[1,3,6] 1.0
# alpha_ibt[1,3,7] 1.0
# alpha_ibt[1,3,8] 1.0
# alpha_ibt[1,3,9] 1.0
# alpha_ibt[1,3,10] 1.0
# alpha_ibt[1,4,1] 1.0
# alpha_ibt[1,4,2] 1.0
# alpha_ibt[1,4,3] 1.0
# alpha_ibt[1,4,4] 1.0
# alpha_ibt[1,4,5] 1.0
# alpha_ibt[1,4,6] 1.0
# alpha_ibt[1,4,7] 1.0
# alpha_ibt[1,4,8] 1.0
# alpha_ibt[1,4,9] 1.0
# alpha_ibt[1,4,10] 1.0
# alpha_ibt[1,5,1] 1.0
# alpha_ibt[1,5,2] 1.0
# alpha_ibt[1,5,3] 1.0
# alpha_ibt[1,5,4] 1.0
# alpha_ibt[1,5,5] 1.0
# alpha_ibt[1,5,6] 1.0
# alpha_ibt[1,5,7] 1.0
# alpha_ibt[1,5,8] 1.0
# alpha_ibt[1,5,9] 1.0
# alpha_ibt[1,5,10] 1.0
# alpha_ibt[1,6,1] 1.0
# alpha_ibt[1,6,2] 1.0
# alpha_ibt[1,6,3] 1.0
# alpha_ibt[1,6,4] 1.0
# alpha_ibt[1,6,5] 1.0
# alpha_ibt[1,6,6] 1.0
# alpha_ibt[1,6,7] 1.0
# alpha_ibt[1,6,8] 1.0
# alpha_ibt[1,6,9] 1.0
# alpha_ibt[1,6,10] 1.0
# alpha_ibt[1,7,1] 1.0
# alpha_ibt[1,7,2] 1.0
# alpha_ibt[1,7,3] 1.0
# alpha_ibt[1,7,4] 1.0
# alpha_ibt[1,7,5] 1.0
# alpha_ibt[1,7,6] 1.0
# alpha_ibt[1,7,7] 1.0
# alpha_ibt[1,7,8] 1.0
# alpha_ibt[1,7,9] 1.0
# alpha_ibt[1,7,10] 1.0
# alpha_ibt[1,8,1] 1.0
# alpha_ibt[1,8,2] 1.0
# alpha_ibt[1,8,3] 1.0
# alpha_ibt[1,8,4] 1.0
# alpha_ibt[1,8,5] 1.0
# alpha_ibt[1,8,6] 1.0
# alpha_ibt[1,8,7] 1.0
# alpha_ibt[1,8,8] 1.0
# alpha_ibt[1,8,9] 1.0
# alpha_ibt[1,8,10] 1.0
# alpha_ibt[1,9,1] 1.0
# alpha_ibt[1,9,2] 1.0
# alpha_ibt[1,9,3] 1.0
# alpha_ibt[1,9,4] 1.0
# alpha_ibt[1,9,5] 1.0
# alpha_ibt[1,9,6] 1.0
# alpha_ibt[1,9,7] 1.0
# alpha_ibt[1,9,8] 1.0
# alpha_ibt[1,9,9] 1.0
# alpha_ibt[1,9,10] 1.0
# alpha_ibt[1,10,1] 1.0
# alpha_ibt[1,10,2] 1.0
# alpha_ibt[1,10,3] 1.0
# alpha_ibt[1,10,4] 1.0
# alpha_ibt[1,10,5] 1.0
# alpha_ibt[1,10,6] 1.0
# alpha_ibt[1,10,7] 1.0
# alpha_ibt[1,10,8] 1.0
# alpha_ibt[1,10,9] 1.0
# alpha_ibt[1,10,10] 1.0
# alpha_ibt[1,11,1] 1.0
# alpha_ibt[1,11,2] 1.0
# alpha_ibt[1,11,3] 1.0
# alpha_ibt[1,11,4] 1.0
# alpha_ibt[1,11,5] 1.0
# alpha_ibt[1,11,6] 1.0
# alpha_ibt[1,11,7] 1.0
# alpha_ibt[1,11,8] 1.0
# alpha_ibt[1,11,9] 1.0
# alpha_ibt[1,11,10] 1.0
# alpha_ibt[1,12,1] 1.0
# alpha_ibt[1,12,2] 1.0
# alpha_ibt[1,12,3] 1.0
# alpha_ibt[1,12,4] 1.0
# alpha_ibt[1,12,5] 1.0
# alpha_ibt[1,12,6] 1.0
# alpha_ibt[1,12,7] 1.0
# alpha_ibt[1,12,8] 1.0
# alpha_ibt[1,12,9] 1.0
# alpha_ibt[1,12,10] 1.0
# alpha_ibt[1,13,1] 1.0
# alpha_ibt[1,13,2] 1.0
# alpha_ibt[1,13,3] 1.0
# alpha_ibt[1,13,4] 1.0
# alpha_ibt[1,13,5] 1.0
# alpha_ibt[1,13,6] 1.0
# alpha_ibt[1,13,7] 1.0
# alpha_ibt[1,13,8] 1.0
# alpha_ibt[1,13,9] 1.0
# alpha_ibt[1,13,10] 1.0
# alpha_ibt[1,14,1] 1.0
# alpha_ibt[1,14,2] 1.0
# alpha_ibt[1,14,3] 1.0
# alpha_ibt[1,14,4] 1.0
# alpha_ibt[1,14,5] 1.0
# alpha_ibt[1,14,6] 1.0
# alpha_ibt[1,14,7] 1.0
# alpha_ibt[1,14,8] 1.0
# alpha_ibt[1,14,9] 1.0
# alpha_ibt[1,14,10] 1.0
# alpha_ibt[1,15,1] 1.0
# alpha_ibt[1,15,2] 1.0
# alpha_ibt[1,15,3] 1.0
# alpha_ibt[1,15,4] 1.0
# alpha_ibt[1,15,5] 1.0
# alpha_ibt[1,15,6] 1.0
# alpha_ibt[1,15,7] 1.0
# alpha_ibt[1,15,8] 1.0
# alpha_ibt[1,15,9] 1.0
# alpha_ibt[1,15,10] 1.0
# alpha_ibt[1,16,1] 1.0
# alpha_ibt[1,16,2] 1.0
# alpha_ibt[1,16,3] 1.0
# alpha_ibt[1,16,4] 1.0
# alpha_ibt[1,16,5] 1.0
# alpha_ibt[1,16,6] 1.0
# alpha_ibt[1,16,7] 1.0
# alpha_ibt[1,16,8] 1.0
# alpha_ibt[1,16,9] 1.0
# alpha_ibt[1,16,10] 1.0
# alpha_ibt[1,17,1] 1.0
# alpha_ibt[1,17,2] 1.0
# alpha_ibt[1,17,3] 1.0
# alpha_ibt[1,17,4] 1.0
# alpha_ibt[1,17,5] 1.0
# alpha_ibt[1,17,6] 1.0
# alpha_ibt[1,17,7] 1.0
# alpha_ibt[1,17,8] 1.0
# alpha_ibt[1,17,9] 1.0
# alpha_ibt[1,18,1] 1.0
# alpha_ibt[1,18,2] 1.0
# alpha_ibt[1,18,3] 1.0
# alpha_ibt[1,18,4] 1.0
# alpha_ibt[1,18,5] 1.0
# alpha_ibt[1,18,6] 1.0
# alpha_ibt[1,18,7] 1.0
# alpha_ibt[1,18,8] 1.0
# alpha_ibt[1,18,9] 1.0
# alpha_ibt[1,19,1] 1.0
# alpha_ibt[1,19,2] 1.0
# alpha_ibt[1,19,3] 1.0
# alpha_ibt[1,19,4] 1.0
# alpha_ibt[1,19,5] 1.0
# alpha_ibt[1,19,6] 1.0
# alpha_ibt[1,19,7] 1.0
# alpha_ibt[1,19,8] 1.0
# alpha_ibt[1,19,9] 1.0
# alpha_ibt[5,2,1] 1.0
# alpha_ibt[5,2,2] 1.0
# alpha_ibt[5,2,3] 1.0
# alpha_ibt[5,2,4] 1.0
# alpha_ibt[5,2,5] 1.0
# alpha_ibt[5,2,6] 1.0
# alpha_ibt[5,2,7] 1.0
# alpha_ibt[5,2,8] 1.0
# alpha_ibt[5,2,9] 1.0
# alpha_ibt[5,2,10] 1.0
# alpha_ibt[5,3,1] 1.0
# alpha_ibt[5,3,2] 1.0
# alpha_ibt[5,3,3] 1.0
# alpha_ibt[5,3,4] 1.0
# alpha_ibt[5,3,5] 1.0
# alpha_ibt[5,3,6] 1.0
# alpha_ibt[5,3,7] 1.0
# alpha_ibt[5,3,8] 1.0
# alpha_ibt[5,3,9] 1.0
# alpha_ibt[5,3,10] 1.0
# alpha_ibt[5,4,1] 1.0
# alpha_ibt[5,4,2] 1.0
# alpha_ibt[5,4,3] 1.0
# alpha_ibt[5,4,4] 1.0
# alpha_ibt[5,4,5] 1.0
# alpha_ibt[5,4,6] 1.0
# alpha_ibt[5,4,7] 1.0
# alpha_ibt[5,4,8] 1.0
# alpha_ibt[5,4,9] 1.0
# alpha_ibt[5,4,10] 1.0
# alpha_ibt[5,5,1] 1.0
# alpha_ibt[5,5,2] 1.0
# alpha_ibt[5,5,3] 1.0
# alpha_ibt[5,5,4] 1.0
# alpha_ibt[5,5,5] 1.0
# alpha_ibt[5,5,6] 1.0
# alpha_ibt[5,5,7] 1.0
# alpha_ibt[5,5,8] 1.0
# alpha_ibt[5,5,9] 1.0
# alpha_ibt[5,5,10] 1.0
# alpha_ibt[5,6,1] 1.0
# alpha_ibt[5,6,2] 1.0
# alpha_ibt[5,6,3] 1.0
# alpha_ibt[5,6,4] 1.0
# alpha_ibt[5,6,5] 1.0
# alpha_ibt[5,6,6] 1.0
# alpha_ibt[5,6,7] 1.0
# alpha_ibt[5,6,8] 1.0
# alpha_ibt[5,6,9] 1.0
# alpha_ibt[5,6,10] 1.0
# alpha_ibt[5,7,1] 1.0
# alpha_ibt[5,7,2] 1.0
# alpha_ibt[5,7,3] 1.0
# alpha_ibt[5,7,4] 1.0
# alpha_ibt[5,7,5] 1.0
# alpha_ibt[5,7,6] 1.0
# alpha_ibt[5,7,7] 1.0
# alpha_ibt[5,7,8] 1.0
# alpha_ibt[5,7,9] 1.0
# alpha_ibt[5,7,10] 1.0
# alpha_ibt[5,8,1] 1.0
# alpha_ibt[5,8,2] 1.0
# alpha_ibt[5,8,3] 1.0
# alpha_ibt[5,8,4] 1.0
# alpha_ibt[5,8,5] 1.0
# alpha_ibt[5,8,6] 1.0
# alpha_ibt[5,8,7] 1.0
# alpha_ibt[5,8,8] 1.0
# alpha_ibt[5,8,9] 1.0
# alpha_ibt[5,8,10] 1.0
# alpha_ibt[5,9,1] 1.0
# alpha_ibt[5,9,2] 1.0
# alpha_ibt[5,9,3] 1.0
# alpha_ibt[5,9,4] 1.0
# alpha_ibt[5,9,5] 1.0
# alpha_ibt[5,9,6] 1.0
# alpha_ibt[5,9,7] 1.0
# alpha_ibt[5,9,8] 1.0
# alpha_ibt[5,9,9] 1.0
# alpha_ibt[5,9,10] 1.0
# alpha_ibt[5,10,1] 1.0
# alpha_ibt[5,10,2] 1.0
# alpha_ibt[5,10,3] 1.0
# alpha_ibt[5,10,4] 1.0
# alpha_ibt[5,10,5] 1.0
# alpha_ibt[5,10,6] 1.0
# alpha_ibt[5,10,7] 1.0
# alpha_ibt[5,10,8] 1.0
# alpha_ibt[5,10,9] 1.0
# alpha_ibt[5,10,10] 1.0
# alpha_ibt[5,11,1] 1.0
# alpha_ibt[5,11,2] 1.0
# alpha_ibt[5,11,3] 1.0
# alpha_ibt[5,11,4] 1.0
# alpha_ibt[5,11,5] 1.0
# alpha_ibt[5,11,6] 1.0
# alpha_ibt[5,11,7] 1.0
# alpha_ibt[5,11,8] 1.0
# alpha_ibt[5,11,9] 1.0
# alpha_ibt[5,11,10] 1.0
# alpha_ibt[5,12,1] 1.0
# alpha_ibt[5,12,2] 1.0
# alpha_ibt[5,12,3] 1.0
# alpha_ibt[5,12,4] 1.0
# alpha_ibt[5,12,5] 1.0
# alpha_ibt[5,12,6] 1.0
# alpha_ibt[5,12,7] 1.0
# alpha_ibt[5,12,8] 1.0
# alpha_ibt[5,12,9] 1.0
# alpha_ibt[5,12,10] 1.0
# alpha_ibt[5,13,1] 1.0
# alpha_ibt[5,13,2] 1.0
# alpha_ibt[5,13,3] 1.0
# alpha_ibt[5,13,4] 1.0
# alpha_ibt[5,13,5] 1.0
# alpha_ibt[5,13,6] 1.0
# alpha_ibt[5,13,7] 1.0
# alpha_ibt[5,13,8] 1.0
# alpha_ibt[5,13,9] 1.0
# alpha_ibt[5,13,10] 1.0
# alpha_ibt[5,14,1] 1.0
# alpha_ibt[5,14,2] 1.0
# alpha_ibt[5,14,3] 1.0
# alpha_ibt[5,14,4] 1.0
# alpha_ibt[5,14,5] 1.0
# alpha_ibt[5,14,6] 1.0
# alpha_ibt[5,14,7] 1.0
# alpha_ibt[5,14,8] 1.0
# alpha_ibt[5,14,9] 1.0
# alpha_ibt[5,14,10] 1.0
# alpha_ibt[5,15,1] 1.0
# alpha_ibt[5,15,2] 1.0
# alpha_ibt[5,15,3] 1.0
# alpha_ibt[5,15,4] 1.0
# alpha_ibt[5,15,5] 1.0
# alpha_ibt[5,15,6] 1.0
# alpha_ibt[5,15,7] 1.0
# alpha_ibt[5,15,8] 1.0
# alpha_ibt[5,15,9] 1.0
# alpha_ibt[5,15,10] 1.0
# alpha_ibt[5,16,1] 1.0
# alpha_ibt[5,16,2] 1.0
# alpha_ibt[5,16,3] 1.0
# alpha_ibt[5,16,4] 1.0
# alpha_ibt[5,16,5] 1.0
# alpha_ibt[5,16,6] 1.0
# alpha_ibt[5,16,7] 1.0
# alpha_ibt[5,16,8] 1.0
# alpha_ibt[5,16,9] 1.0
# alpha_ibt[5,16,10] 1.0
# alpha_ibt[5,17,1] 1.0
# alpha_ibt[5,17,2] 1.0
# alpha_ibt[5,17,3] 1.0
# alpha_ibt[5,17,4] 1.0
# alpha_ibt[5,17,5] 1.0
# alpha_ibt[5,17,6] 1.0
# alpha_ibt[5,17,7] 1.0
# alpha_ibt[5,17,8] 1.0
# alpha_ibt[5,17,9] 1.0
# alpha_ibt[5,18,1] 1.0
# alpha_ibt[5,18,2] 1.0
# alpha_ibt[5,18,3] 1.0
# alpha_ibt[5,18,4] 1.0
# alpha_ibt[5,18,5] 1.0
# alpha_ibt[5,18,6] 1.0
# alpha_ibt[5,18,7] 1.0
# alpha_ibt[5,18,8] 1.0
# alpha_ibt[5,18,9] 1.0
# alpha_ibt[5,19,1] 1.0
# alpha_ibt[5,19,2] 1.0
# alpha_ibt[5,19,3] 1.0
# alpha_ibt[5,19,4] 1.0
# alpha_ibt[5,19,5] 1.0
# alpha_ibt[5,19,6] 1.0
# alpha_ibt[5,19,7] 1.0
# alpha_ibt[5,19,8] 1.0
# alpha_ibt[5,19,9] 1.0
# alpha_ibt[15,5,2] 1.0
# alpha_ibt[15,6,2] 1.0
# alpha_ibt[15,7,2] 1.0
# alpha_ibt[15,8,2] 1.0
# alpha_ibt[15,9,2] 1.0
# alpha_ibt[15,11,8] 1.0
# alpha_ibt[15,18,6] 1.0
# alpha_ibt[15,19,6] 1.0
# alpha_ibt[15,25,5] 1.0
# alpha_ibt[15,26,5] 1.0
# alpha_ibt[15,26,7] 1.0
# alpha_ibt[15,26,9] 1.0
# alpha_ibt[15,27,5] 1.0
# alpha_ibt[15,27,7] 1.0
# alpha_ibt[15,27,9] 1.0
# alpha_ibt[15,28,2] 1.0
# alpha_ibt[15,28,8] 1.0
# alpha_ibt[15,29,1] 1.0
# alpha_ibt[15,29,2] 1.0
# alpha_ibt[15,29,4] 1.0
# alpha_ibt[15,30,1] 1.0
# alpha_ibt[15,30,4] 1.0
# alpha_ibt[15,30,8] 1.0
# alpha_ibt[15,31,8] 1.0
# alpha_ibt[15,32,3] 1.0
# alpha_ibt[15,32,4] 1.0
# alpha_ibt[15,32,8] 1.0
# alpha_ibt[15,33,3] 1.0
# alpha_ibt[15,33,4] 1.0
# alpha_ibt[15,33,8] 1.0
# alpha_ibt[15,34,4] 1.0
# alpha_ibt[15,34,5] 1.0
# alpha_ibt[15,34,10] 1.0
# alpha_ibt[15,35,4] 1.0
# alpha_ibt[15,35,5] 1.0
# alpha_ibt[15,35,10] 1.0
# alpha_ibt[15,36,2] 1.0
# alpha_ibt[15,36,4] 1.0
# alpha_ibt[15,36,5] 1.0
# alpha_ibt[15,36,7] 1.0
# alpha_ibt[15,36,9] 1.0
# alpha_ibt[15,36,10] 1.0
# alpha_ibt[15,37,2] 1.0
# alpha_ibt[15,37,4] 1.0
# alpha_ibt[15,37,7] 1.0
# alpha_ibt[15,37,8] 1.0
# alpha_ibt[15,37,9] 1.0
# alpha_ibt[15,38,2] 1.0
# alpha_ibt[15,38,6] 1.0
# alpha_ibt[15,38,7] 1.0
# alpha_ibt[15,38,8] 1.0
# alpha_ibt[15,39,6] 1.0
# alpha_ibt[15,39,8] 1.0
# alpha_ibt[15,40,2] 1.0
# alpha_ibt[15,40,8] 1.0
# alpha_ibt[15,41,2] 1.0
# alpha_ibt[15,41,4] 1.0
# alpha_ibt[15,41,8] 1.0
# alpha_ibt[15,42,3] 1.0
# alpha_ibt[15,42,4] 1.0
# alpha_ibt[15,42,10] 1.0
# alpha_ibt[15,43,2] 1.0
# alpha_ibt[15,43,3] 1.0
# alpha_ibt[15,43,4] 1.0
# alpha_ibt[15,44,2] 1.0
# alpha_ibt[15,44,3] 1.0
# alpha_ibt[15,44,5] 1.0
# alpha_ibt[15,44,6] 1.0
# alpha_ibt[15,45,1] 1.0
# alpha_ibt[15,45,2] 1.0
# alpha_ibt[15,45,3] 1.0
# alpha_ibt[15,45,4] 1.0
# alpha_ibt[15,45,5] 1.0
# alpha_ibt[15,45,6] 1.0
# alpha_ibt[15,45,7] 1.0
# alpha_ibt[15,45,8] 1.0
# alpha_ibt[15,45,9] 1.0
# alpha_ibt[15,45,10] 1.0
# alpha_ibt[15,46,1] 1.0
# alpha_ibt[15,46,2] 1.0
# alpha_ibt[15,46,4] 1.0
# alpha_ibt[15,46,5] 1.0
# alpha_ibt[15,46,6] 1.0
# alpha_ibt[15,46,10] 1.0
# alpha_ibt[15,47,1] 1.0
# alpha_ibt[15,47,2] 1.0
# alpha_ibt[15,47,3] 1.0
# alpha_ibt[15,47,4] 1.0
# alpha_ibt[15,47,5] 1.0
# alpha_ibt[15,47,6] 1.0
# alpha_ibt[15,47,7] 1.0
# alpha_ibt[15,47,8] 1.0
# alpha_ibt[15,47,9] 1.0
# alpha_ibt[15,47,10] 1.0
# alpha_ibt[15,48,1] 1.0
# alpha_ibt[15,48,2] 1.0
# alpha_ibt[15,48,3] 1.0
# alpha_ibt[15,48,4] 1.0
# alpha_ibt[15,48,5] 1.0
# alpha_ibt[15,48,6] 1.0
# alpha_ibt[15,48,7] 1.0
# alpha_ibt[15,48,8] 1.0
# alpha_ibt[15,48,9] 1.0
# alpha_ibt[15,48,10] 1.0
# alpha_ibt[16,2,2] 1.0
# alpha_ibt[16,2,3] 1.0
# alpha_ibt[16,2,4] 1.0
# alpha_ibt[16,2,5] 1.0
# alpha_ibt[16,2,6] 1.0
# alpha_ibt[16,2,7] 1.0
# alpha_ibt[16,2,9] 1.0
# alpha_ibt[16,2,10] 1.0
# alpha_ibt[16,3,1] 1.0
# alpha_ibt[16,3,2] 1.0
# alpha_ibt[16,3,3] 1.0
# alpha_ibt[16,3,4] 1.0
# alpha_ibt[16,3,5] 1.0
# alpha_ibt[16,3,6] 1.0
# alpha_ibt[16,3,7] 1.0
# alpha_ibt[16,3,8] 1.0
# alpha_ibt[16,3,9] 1.0
# alpha_ibt[16,3,10] 1.0
# alpha_ibt[16,4,5] 1.0
# alpha_ibt[16,4,8] 1.0
# alpha_ibt[16,4,10] 1.0
# alpha_ibt[16,5,8] 1.0
# alpha_ibt[16,5,10] 1.0
# alpha_ibt[16,6,1] 1.0
# alpha_ibt[16,6,3] 1.0
# alpha_ibt[16,6,6] 1.0
# alpha_ibt[16,6,8] 1.0
# alpha_ibt[16,7,8] 1.0
# alpha_ibt[16,7,9] 1.0
# alpha_ibt[16,8,8] 1.0
# alpha_ibt[16,9,1] 1.0
# alpha_ibt[16,9,2] 1.0
# alpha_ibt[16,9,3] 1.0
# alpha_ibt[16,9,4] 1.0
# alpha_ibt[16,9,5] 1.0
# alpha_ibt[16,9,6] 1.0
# alpha_ibt[16,9,7] 1.0
# alpha_ibt[16,9,8] 1.0
# alpha_ibt[16,9,9] 1.0
# alpha_ibt[16,9,10] 1.0
# alpha_ibt[16,10,8] 1.0
# alpha_ibt[16,10,10] 1.0
# alpha_ibt[16,11,8] 1.0
# alpha_ibt[16,13,8] 1.0
# alpha_ibt[16,14,8] 1.0
# alpha_ibt[16,16,1] 1.0
# alpha_ibt[16,16,2] 1.0
# alpha_ibt[16,16,3] 1.0
# alpha_ibt[16,16,4] 1.0
# alpha_ibt[16,16,5] 1.0
# alpha_ibt[16,16,6] 1.0
# alpha_ibt[16,16,7] 1.0
# alpha_ibt[16,16,8] 1.0
# alpha_ibt[16,16,9] 1.0
# alpha_ibt[16,16,10] 1.0
# alpha_ibt[16,17,3] 1.0
# alpha_ibt[16,19,1] 1.0
# alpha_ibt[16,19,5] 1.0
# alpha_ibt[16,20,5] 1.0
# alpha_ibt[16,21,5] 1.0
# alpha_ibt[16,21,6] 1.0
# alpha_ibt[16,22,5] 1.0
# alpha_ibt[16,22,6] 1.0
# alpha_ibt[16,23,5] 1.0
# alpha_ibt[16,23,6] 1.0
# alpha_ibt[16,26,2] 1.0
# alpha_ibt[16,27,2] 1.0
# alpha_ibt[16,27,6] 1.0
# alpha_ibt[16,28,2] 1.0
# alpha_ibt[16,29,7] 1.0
# alpha_ibt[16,29,9] 1.0
# alpha_ibt[16,30,2] 1.0
# alpha_ibt[16,30,7] 1.0
# alpha_ibt[16,30,9] 1.0
# alpha_ibt[16,31,2] 1.0
# alpha_ibt[16,31,5] 1.0
# alpha_ibt[16,31,7] 1.0
# alpha_ibt[16,31,9] 1.0
# alpha_ibt[16,31,10] 1.0
# alpha_ibt[16,32,1] 1.0
# alpha_ibt[16,32,2] 1.0
# alpha_ibt[16,32,4] 1.0
# alpha_ibt[16,32,5] 1.0
# alpha_ibt[16,32,8] 1.0
# alpha_ibt[16,32,10] 1.0
# alpha_ibt[16,33,1] 1.0
# alpha_ibt[16,33,2] 1.0
# alpha_ibt[16,33,4] 1.0
# alpha_ibt[16,33,5] 1.0
# alpha_ibt[16,33,6] 1.0
# alpha_ibt[16,33,7] 1.0
# alpha_ibt[16,33,8] 1.0
# alpha_ibt[16,34,1] 1.0
# alpha_ibt[16,34,2] 1.0
# alpha_ibt[16,34,4] 1.0
# alpha_ibt[16,34,5] 1.0
# alpha_ibt[16,34,6] 1.0
# alpha_ibt[16,34,7] 1.0
# alpha_ibt[16,34,8] 1.0
# alpha_ibt[16,35,3] 1.0
# alpha_ibt[16,35,5] 1.0
# alpha_ibt[16,35,6] 1.0
# alpha_ibt[16,35,8] 1.0
# alpha_ibt[16,36,3] 1.0
# alpha_ibt[16,36,6] 1.0
# alpha_ibt[16,36,8] 1.0
# alpha_ibt[16,37,3] 1.0
# alpha_ibt[16,37,6] 1.0
# alpha_ibt[16,37,10] 1.0
# alpha_ibt[16,38,2] 1.0
# alpha_ibt[16,38,4] 1.0
# alpha_ibt[16,38,7] 1.0
# alpha_ibt[16,38,8] 1.0
# alpha_ibt[16,38,10] 1.0
# alpha_ibt[16,39,1] 1.0
# alpha_ibt[16,39,2] 1.0
# alpha_ibt[16,39,3] 1.0
# alpha_ibt[16,39,4] 1.0
# alpha_ibt[16,39,7] 1.0
# alpha_ibt[16,39,8] 1.0
# alpha_ibt[16,39,9] 1.0
# alpha_ibt[16,39,10] 1.0
# alpha_ibt[16,40,1] 1.0
# alpha_ibt[16,40,3] 1.0
# alpha_ibt[16,40,7] 1.0
# alpha_ibt[16,40,9] 1.0
# alpha_ibt[16,41,1] 1.0
# alpha_ibt[16,41,4] 1.0
# alpha_ibt[16,41,6] 1.0
# alpha_ibt[16,41,7] 1.0
# alpha_ibt[16,41,9] 1.0
# alpha_ibt[16,42,1] 1.0
# alpha_ibt[16,42,2] 1.0
# alpha_ibt[16,42,4] 1.0
# alpha_ibt[16,42,5] 1.0
# alpha_ibt[16,42,6] 1.0
# alpha_ibt[16,42,7] 1.0
# alpha_ibt[16,42,8] 1.0
# alpha_ibt[16,43,1] 1.0
# alpha_ibt[16,43,2] 1.0
# alpha_ibt[16,43,5] 1.0
# alpha_ibt[16,43,6] 1.0
# alpha_ibt[16,43,7] 1.0
# alpha_ibt[16,43,8] 1.0
# alpha_ibt[16,43,10] 1.0
# alpha_ibt[16,44,6] 1.0
# alpha_ibt[16,44,7] 1.0
# alpha_ibt[16,44,8] 1.0
# alpha_ibt[16,44,10] 1.0
# alpha_ibt[16,45,1] 1.0
# alpha_ibt[16,45,2] 1.0
# alpha_ibt[16,45,3] 1.0
# alpha_ibt[16,45,4] 1.0
# alpha_ibt[16,45,5] 1.0
# alpha_ibt[16,45,6] 1.0
# alpha_ibt[16,45,7] 1.0
# alpha_ibt[16,45,8] 1.0
# alpha_ibt[16,45,9] 1.0
# alpha_ibt[16,45,10] 1.0
# alpha_ibt[16,46,2] 1.0
# alpha_ibt[16,46,3] 1.0
# alpha_ibt[16,46,5] 1.0
# alpha_ibt[16,46,6] 1.0
# alpha_ibt[16,46,7] 1.0
# alpha_ibt[16,46,8] 1.0
# alpha_ibt[16,46,9] 1.0
# alpha_ibt[16,46,10] 1.0
# alpha_ibt[16,47,1] 1.0
# alpha_ibt[16,47,2] 1.0
# alpha_ibt[16,47,3] 1.0
# alpha_ibt[16,47,4] 1.0
# alpha_ibt[16,47,5] 1.0
# alpha_ibt[16,47,6] 1.0
# alpha_ibt[16,47,7] 1.0
# alpha_ibt[16,47,8] 1.0
# alpha_ibt[16,47,9] 1.0
# alpha_ibt[16,47,10] 1.0
# alpha_ibt[16,48,1] 1.0
# alpha_ibt[16,48,2] 1.0
# alpha_ibt[16,48,3] 1.0
# alpha_ibt[16,48,4] 1.0
# alpha_ibt[16,48,5] 1.0
# alpha_ibt[16,48,6] 1.0
# alpha_ibt[16,48,7] 1.0
# alpha_ibt[16,48,8] 1.0
# alpha_ibt[16,48,9] 1.0
# alpha_ibt[16,48,10] 1.0
